# %% [markdown]
# <a href="https://colab.research.google.com/github/borderbollie/1111/blob/main/List(matplotlib_pyplot)%E7%B9%AA%E8%A3%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [1,2,3,2,1]

y = [3,2,1,2,3]

plt.plot(x)
plt.plot(y)
